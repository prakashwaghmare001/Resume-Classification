# %%
import os
import pandas as pd
from docx import Document
import PyPDF2
import random

# %% [markdown]
# # Converting DOC files to DOCX files

# %%
import os
import win32com.client

def doc_to_docx():
    wdFormatDocx = 16
    word = win32com.client.Dispatch('Word.Application')
    for root, dirs, files in os.walk(os.getcwd()):
        for file in files:
            if file.endswith(".doc"):
                doc_file = os.path.join(root, file)
                docx_file = os.path.join(root, file + "x")
                doc = word.Documents.Open(doc_file)
                doc.SaveAs2(docx_file, FileFormat=wdFormatDocx)
                doc.Close()
    word.Quit()

doc_to_docx()

# %% [markdown]
# deleting unnessesory doc files

# %%
def docdel():
  for root, dirs, files in os.walk('.'):
    for file in files:
      if file.endswith('.doc'):
        os.remove(os.path.join(root, file))

docdel()

# %% [markdown]
# # extracting data from files

# %% [markdown]
# extracting data from 1 folder at a time

# %% [markdown]
# # React Dev

# %%
# Folder path where resume are stored
resumes_dir = "Resumes/React Developer"

# Define the job role for all resumes
job_role = 'React Developer'
# Empty list to store the resume data
resume_data = []

# Loop through each file in the resumes directory
for filename in os.listdir(resumes_dir):
    file_path = os.path.join(resumes_dir, filename)
    
    # Check if the file is a Microsoft Word document
    if filename.endswith('.docx'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])
    
    # Check if the file is a Microsoft Word 97-2003 document
    #elif filename.endswith('.doc'):
    #    document = Document(file_path)
    #    text = '\n'.join([paragraph.text for paragraph in document.paragraphs])
        
    # Check if the file is a PDF
    elif filename.endswith('.pdf'):
        with open(file_path, 'rb') as f:
            pdf_reader = PyPDF2.PdfReader(f)
            text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()

    # Add the resume data to the list
    resume_data.append({'text': text, 'job_role': job_role})

# Convert the list of dictionaries to a pandas DataFrame
react_dev = pd.DataFrame(resume_data)

# Print the DataFrame
react_dev
# Out:
#                                                  text         job_role
# 0   Name: Ravali P \n\n                           ...  React Developer
# 1     \nSUSOVAN  BAG   \nSeeking  a  challenging  ...  React Developer
# 2   Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...  React Developer
# 3   HARIPRIYA BATTINA \nExperience as UI Developer...  React Developer
# 4   KAMALAKAR REDDY. A \nLinked In: https://www.li...  React Developer
# 5   \nNaveen Sadhu\n\n\nTitle: software developer\...  React Developer
# 6   \n\n\nPROFILE\nSearching for the opportunity t...  React Developer
# 7    \nPRAGNYA PATTNAIK\n \n \n \n Expertise: \n \...  React Developer
# 8   \n\n 204,Sri geethika prestige,road number 10...  React Developer
# 9   \n\nThirupathamma Balla\n\nSUMMARY:\n\n2.8 yea...  React Developer
# 10  Maryala Vinay Reddy\n\nProfessional Summary:\t...  React Developer
# 11  \nUi-Developer/ React JS Developer \nNAME: KRI...  React Developer
# ...

# %%
react_dev.loc[20]["text"]
# Out:
# '   \nPage | 1  \n Name: M. Prabakaran  \nTitle: UI Developer  \n \nPROFESSIONAL SUMMARY  \n \n● 2.4+ years of Professional IT experience as a software developer having knowledge on different UI based \nApplication.  \n● Hands on experience in HTML, CSS, JS, ReactJS.   \n● Hands on experience in handling UI interaction, Design methodology.  \n● Handling In -App purchase, uploading and maintaining apps in play store.  \n● Hands on experience with customization over base -product depends on  client requirement.  \n● Cohesive team worker, having strong analytical, problem solving and interpersonal skills.  \n \nEDUCATION  \n \n● Completed on 2017 Bachelor of Technology (ECE) , PRIST University, Tamil Nadu.  \n● Completed on 2012 Higher Secondary , Mount Park Hr Sec School , Thiyagadurgam,  Tamil Nadu.  \n● Completed on 2010 SSLC , Krishnasamy Hr Sec School , Cuddalore,  Tamil Nadu.  \n \nSKILLS  \n \nOperating System  Windows, Unix,Mac  \nProgramming Languages  HTML, CSS, JS, React  \nM
# ...

# %% [markdown]
# # Sql Dev

# %%
resumes_dir = "Resumes/SQL Developer"

job_role = 'SQL Developer'

resume_data = []

for filename in os.listdir(resumes_dir):
    file_path = os.path.join(resumes_dir, filename)

    if filename.endswith('.docx'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])

    elif filename.endswith('.doc'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])

    elif filename.endswith('.pdf'):
        with open(file_path, 'rb') as f:
            pdf_reader = PyPDF2.PdfReader(f)
            text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()

    resume_data.append({'text': text, 'job_role': job_role})

sql_dev = pd.DataFrame(resume_data)

sql_dev
# Out:
#                                                  text       job_role
# 0   ANIL KUMAR MADDUKURI  \t\t\nSQL & MSBI Develop...  SQL Developer
# 1   \nAradhana Tripathi\n\nCurrent Location: Gachi...  SQL Developer
# 2   BUDDHA VAMSI                                  ...  SQL Developer
# 3   KAMBALLA PRADEEP                              ...  SQL Developer
# 4   \n\n\n Hyderabad\n\nNazeer Basha\nSQL and Pow...  SQL Developer
# 5    \n                                        Res...  SQL Developer
# 6   SQL DEVELOPER\nName: -   Bandi prem sai\n\n\nW...  SQL Developer
# 7                                          SQL SER...  SQL Developer
# 8                                          SQL SER...  SQL Developer
# 9    RAJU PAVANA KUMARI\n\n\nProfessional Summary:...  SQL Developer
# 10                                      resume\n\n...  SQL Developer
# 11  Name: Ramesh\n\nCareer Objective: \n          ...  SQL Developer
# 12  Career objective\n\t\nA rewarding opportunity ...  SQL Developer
# ...

# %% [markdown]
# # Peoplesoft

# %%
resumes_dir = "Resumes/Peoplesoft"

job_role = 'Peoplesoft'

resume_data = []

for filename in os.listdir(resumes_dir):
    file_path = os.path.join(resumes_dir, filename)

    if filename.endswith('.docx'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])
 
    elif filename.endswith('.doc'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])

    elif filename.endswith('.pdf'):
        with open(file_path, 'rb') as f:
            pdf_reader = PyPDF2.PdfReader(f)
            text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()

    resume_data.append({'text': text, 'job_role': job_role})

people_soft_dba = pd.DataFrame(resume_data)

people_soft_dba
# Out:
#                                                  text    job_role
# 0     Anubhav Kumar Singh\t\t\n\n  To work in a gl...  Peoplesoft
# 1   \n\n\n\n\n\n\t\n\nProfile Summary:\t\t\t\t\t\t...  Peoplesoft
# 2   PeopleSoft Database Administrator\n           ...  Peoplesoft
# 3   Murali\n\nExperience Summary \n\nI have 6 year...  Peoplesoft
# 4   Priyanka Ramadoss\n61/46, MountPleasant, \nCoo...  Peoplesoft
# 5   \n\n\n\n\n\n\n\n\n\n\n\n\n\nPROFILE SUMMARY\n\...  Peoplesoft
# 6   PEOPLESOFT Administrator\n\n\nSRINIVAS.K \t\t\...  Peoplesoft
# 7    PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...  Peoplesoft
# 8   Vinod Akkala                                  ...  Peoplesoft
# 9    PeopleSoft Admin/PeopleSoft DBA\n\nGanesh All...  Peoplesoft
# 10  PeopleSoft Administration\n \nVivekanand Sayan...  Peoplesoft
# 11  Arun Venu\n\n  EXPERIENCE SUMMARY\t\n\nExperie...  Peoplesoft
# 12  \n\n\n\n\nExperience Summary\n4.1 years- Exper...  Peoplesoft
# ...

# %% [markdown]
# # Workday Consultant

# %%
resumes_dir = "Resumes/Workday"

job_role = "Workday"

resume_data = []

for filename in os.listdir(resumes_dir):
    file_path = os.path.join(resumes_dir, filename)
    
    if filename.endswith('.docx'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])

    elif filename.endswith('.doc'):
        document = Document(file_path)
        text = '\n'.join([paragraph.text for paragraph in document.paragraphs])

    elif filename.endswith('.pdf'):
        with open(file_path, 'rb') as f:
            pdf_reader = PyPDF2.PdfReader(f)
            text = ''
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text()
    resume_data.append({'text': text, 'job_role': job_role})

workday_consultant = pd.DataFrame(resume_data)

workday_consultant
# Out:
#                                                  text job_role
# 0   Chinna Subbarayudu M\nDOB: 06th March 1994\nNa...  Workday
# 1   \t\n\n\nName         : Gopi Krishna Reddy\n\t\...  Workday
# 2   Hari Krishna M\n\n\nSummary:\nA result oriente...  Workday
# 3   Harikrishna Akula                             ...  Workday
# 4   HIMA.MENDU\n  \n\nCareer Objective\nTo continu...  Workday
# 5                                         \n      ...  Workday
# 6   \t\t\t\t\t\t\tName:\tJ. Sumanth Royal.\n\t\nPR...  Workday
# 7   \n\nJYOTI VERMA\t\t\t\t\t\n\n\n\n3 years of Ex...  Workday
# 8   \t\t\t\t\tMadeeswar A\n\t\n\t\nPROFILE SUMMARY...  Workday
# 9   \n\nMooraboyina Guravaiah\nWorkday Integration...  Workday
# 10  Name\t: Naresh Babu Cherukuri\n\nObjective:\nT...  Workday
# 11  VENKATA SAIKRISHNA\n Workday Consultant\n\n\nP...  Workday
# 12  \n\n\n3.3 years of IT experience as Workday HC...  Workday
# 13  Rahul  (Techno Functional Consultant)  \nProfe...  Workday
# ...

# %% [markdown]
# # creating dataframe for all

# %%
# Concate pandas dataframe 
df=pd.concat([people_soft_dba,sql_dev,react_dev,workday_consultant])
#Shuffle the rows 
df=df.sample(frac=1).reset_index(drop=True)
#print the shape of dataframe
print(df.shape)
# Print the first 5 rows of the DataFrame
df.head()
# Out:
# (79, 2)
#                                                 text         job_role
# 0  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...          Workday
# 1                                      resume\n\n...    SQL Developer
# 2  Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...       Peoplesoft
# 3  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...  React Developer
# 4   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...       Peoplesoft

# %% [markdown]
# Checking data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      79 non-null     object
#  1   job_role  79 non-null     object
# dtypes: object(2)
# memory usage: 1.4+ KB

# %%
df.index.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False])

# %%
#resume_data = resume_data[["Category", "Raw_Details"]]
df.rename(columns={'text': 'Raw_Details'}, inplace=True)
df.rename(columns={'job_role':'Category'}, inplace=True)
df=df[["Category", "Raw_Details"]]

# %%
df
# Out:
#            Category                                        Raw_Details
# 0           Workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 1     SQL Developer                                      resume\n\n...
# 2        Peoplesoft  Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...
# 3   React Developer  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...
# 4        Peoplesoft   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...
# ..              ...                                                ...
# 74  React Developer  \n\n 204,Sri geethika prestige,road number 10...
# 75       Peoplesoft  Vinod Akkala                                  ...
# 76    SQL Developer   \n                                        Res...
# 77  React Developer  Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...
# 78          Workday  HIMA.MENDU\n  \n\nCareer Objective\nTo continu...
#
# [79 rows x 2 columns]

# %%
df.loc[78]["Raw_Details"]
# Out:
# 'HIMA.MENDU\n  \n\nCareer Objective\nTo continue growing in knowledge and skills in cloud-based HR solutions by beginning with challenging Workday assignments which would value add to the organization and my professional merit.\n\nCareer Stream - Current\n\nWorking on Workday HCM based production support assignment handling both functional and integration tickets. \n\n\nMy Growth Path\n\nWorking as workday consultant at Accenture, Hyderabad from Jan 2018 till date (Parent Company- I-Fact Technologies).\nWorked as HR Executive Q Ventures pvt Ltd, Hyderabad from April 2011 to Dec 2014.\nMaternity Leave from January 2015 to Dec 2017.  \n\n    \nProfessional Summary      \nHR Systems - ERP (Workday)                      \n                                                                                             \t\t\t  \nKnowledge in Workday Functional concepts (Events, Tasks & Business Processes related to Core HCM) including Supervisory Organizations, Jobs & Positions, Business Proce
# ...

# %%
df["Raw_Details"]
# Out:
# 0     Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 1                                         resume\n\n...
# 2     Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...
# 3     KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...
# 4      PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...
#                             ...
# 74    \n\n 204,Sri geethika prestige,road number 10...
# 75    Vinod Akkala                                  ...
# 76     \n                                        Res...
# 77    Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...
# 78    HIMA.MENDU\n  \n\nCareer Objective\nTo continu...
# Name: Raw_Details, Length: 79, dtype: object

# %% [markdown]
# # Saving all data as csv

# %%
df.to_csv('Raw_Resume.csv', index=False)

# %% [markdown]
# # test of csv

# %%
resume_data = pd.read_csv("Raw_Resume.csv")
resume_data
# Out:
#            Category                                        Raw_Details
# 0           Workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 1     SQL Developer                                      resume\n\n...
# 2        Peoplesoft  Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...
# 3   React Developer  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...
# 4        Peoplesoft   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...
# ..              ...                                                ...
# 74  React Developer  \n\n 204,Sri geethika prestige,road number 10...
# 75       Peoplesoft  Vinod Akkala                                  ...
# 76    SQL Developer   \n                                        Res...
# 77  React Developer  Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...
# 78          Workday  HIMA.MENDU\n  \n\nCareer Objective\nTo continu...
#
# [79 rows x 2 columns]

# %% [markdown]
# ### Number of Words in each Resume

# %%
resume_data['Word_Count'] = resume_data['Raw_Details'].apply(lambda x: len(str(x).split(" ")))
resume_data[['Raw_Details','Word_Count']].head()
# Out:
#                                          Raw_Details  Word_Count
# 0  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         687
# 1                                      resume\n\n...         745
# 2  Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...         363
# 3  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...         333
# 4   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...         881

# %% [markdown]
# ### Number of Characters

# %%
resume_data['Char_Count'] = resume_data['Raw_Details'].str.len() ## this also includes spaces
resume_data[['Raw_Details','Char_Count']].head()
# Out:
#                                          Raw_Details  Char_Count
# 0  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...        5381
# 1                                      resume\n\n...        4085
# 2  Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...        2732
# 3  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...        1568
# 4   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...        7265

# %% [markdown]
# ### Number of Stopwords

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
resume_data['Stopwords'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x in stop]))
resume_data[['Raw_Details','Stopwords']].head()
# Out:
#                                          Raw_Details  Stopwords
# 0  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...        156
# 1                                      resume\n\n...        154
# 2  Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...         98
# 3  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...         41
# 4   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...        224

# %% [markdown]
# ### Number of Numerics

# %%
resume_data['Numerics'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
resume_data[['Raw_Details','Numerics']].head()
# Out:
#                                          Raw_Details  Numerics
# 0  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         1
# 1                                      resume\n\n...         4
# 2  Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...         4
# 3  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...         7
# 4   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...         3

# %%
resume_data
# Out:
#            Category                                        Raw_Details  \
# 0           Workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 1     SQL Developer                                      resume\n\n...
# 2        Peoplesoft  Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...
# 3   React Developer  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...
# 4        Peoplesoft   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...
# ..              ...                                                ...
# 74  React Developer  \n\n 204,Sri geethika prestige,road number 10...
# 75       Peoplesoft  Vinod Akkala                                  ...
# 76    SQL Developer   \n                                        Res...
# 77  React Developer  Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...
# 78          Workday  HIMA.MENDU\n  \n\nCareer Objective\nTo continu...
#
#     Word_Count  Char_Count  Stopwords  Numerics
# 0          687        5381        156         1
# ...

# %% [markdown]
# ## Text Pre-Processing

# %% [markdown]
# ###  Using Regular Expression

# %%
import os
import re
import nltk
import spacy
import string
import textract
import pandas as pd
import seaborn as sns
from matplotlib import pylab
from matplotlib import pyplot as plt

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from wordcloud import WordCloud, STOPWORDS
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer

import warnings
warnings.filterwarnings('ignore')

# %%
def preprocess(sentence):
    sentence = str(sentence)
    sentence = sentence.lower()
    sentence = sentence.replace('using', '')
    sentence = sentence.replace('work', '')
    sentence = sentence.replace('used', '')
    sentence = sentence.replace('good', '')
    sentence = sentence.replace('various', '')
    sentence = sentence.replace('bad', '')
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_url = re.sub(r'http\S+', '',cleantext)
    rem_num = re.sub('[0-9]+', '', rem_url)
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(rem_num)  
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]

    return " ".join(filtered_words)

# %%
resume_data['Resume_Details'] = resume_data.Raw_Details.apply(lambda x: preprocess(x))

# %% [markdown]
# ###  Clean Text from Resume

# %%
resume_data
# Out:
#            Category                                        Raw_Details  \
# 0           Workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 1     SQL Developer                                      resume\n\n...
# 2        Peoplesoft  Tanna Sujatha \n\n\n\nOBJECTIVE\nSeeking a cha...
# 3   React Developer  KAMBALA SAI SURENDRA   \n \n\tMandepeta \t \n ...
# 4        Peoplesoft   PeopleSoft Admin\nVARKALA VIKAS\n\nCareer Obj...
# ..              ...                                                ...
# 74  React Developer  \n\n 204,Sri geethika prestige,road number 10...
# 75       Peoplesoft  Vinod Akkala                                  ...
# 76    SQL Developer   \n                                        Res...
# 77  React Developer  Kanumuru Deepak Reddy\n\n\n\nCAREER OBJECTIVE:...
# 78          Workday  HIMA.MENDU\n  \n\nCareer Objective\nTo continu...
#
#                                        Resume_Details
# 0   ramesh day hcm consultant professional summary...
# ...

# %% [markdown]
# ### Save the Clean Data in new CSV File

# %%
resume_data.drop(['Raw_Details'], axis = 1, inplace = True)
resume_data
# Out:
#            Category                                     Resume_Details
# 0           Workday  ramesh day hcm consultant professional summary...
# 1     SQL Developer  resume ramalakshmi career objective profession...
# 2        Peoplesoft  tanna sujatha objective seeking challenging ro...
# 3   React Developer  kambala sai surendra mandepeta summary project...
# 4        Peoplesoft  peoplesoft admin varkala vikas career objectiv...
# ..              ...                                                ...
# 74  React Developer  sri geethika prestige road number bandari layo...
# 75       Peoplesoft  vinod akkala peoplesoft dba admin professional...
# 76    SQL Developer  resume name neeraj mishra year month experienc...
# 77  React Developer  kanumuru deepak reddy career objective secure ...
# 78          Workday  hima mendu career objective continue growing k...
#
# [79 rows x 2 columns]

# %%
resume_data.to_csv('Cleaned_Resumes.csv', index = False)

# %%
resume_data = pd.read_csv('Cleaned_Resumes.csv')
resume_data
# Out:
#            Category                                     Resume_Details
# 0           Workday  ramesh workday hcm consultant professional sum...
# 1     SQL Developer  resume ramalakshmi career objective profession...
# 2        Peoplesoft  tanna sujatha objective seeking challenging ro...
# 3   React Developer  kambala sai surendra mandepeta summary project...
# 4        Peoplesoft  peoplesoft admin varkala vikas career objectiv...
# ..              ...                                                ...
# 74  React Developer  sri geethika prestige road number bandari layo...
# 75       Peoplesoft  vinod akkala peoplesoft dba admin professional...
# 76    SQL Developer  resume name neeraj mishra year month experienc...
# 77  React Developer  kanumuru deepak reddy career objective secure ...
# 78          Workday  hima mendu career objective continue growing k...
#
# [79 rows x 2 columns]

# %%
resume_data.Resume_Details[5]
# Out:
# 'anil kumar maddukuri sql msbi developer summary years experience sql server ssms creating ssis packages ssrs reports using microsoft business intelligence msbi tools expertise various types joins sub queries writing complex queries involving multiple tables handled data manipulation data consistency creating views triggers synonyms hands experience creation optimization debugging stored procedure functions familiar writing queries using cte temporary tables table variables good experience using set operators like union union except intersect assist required data experience manipulate data multiple table report client using aggregate functions windows functions string functions worked extensively data extraction transformation loading etl process sql server integration services used containers loop container sequence container load data multiple source file database tables expertise using tasks like data flow task execute sql task control flow task execute package task execute proces
# ...

# %% [markdown]
# ## Named Entity Recognition (NER)

# %%
oneSetOfStopWords = set(stopwords.words('english')+['``',"''"])
totalWords =[]
Sentences = resume_data['Resume_Details'].values
cleanedSentences = ""
for records in Sentences:
    cleanedText = preprocess(records)
    cleanedSentences += cleanedText
    requiredWords = nltk.word_tokenize(cleanedText)
    for word in requiredWords:
        if word not in oneSetOfStopWords and word not in string.punctuation:
            totalWords.append(word)
    
wordfreqdist = nltk.FreqDist(totalWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)
# Out:
# [('experience', 564), ('peoplesoft', 395), ('using', 375), ('application', 369), ('workday', 367), ('server', 326), ('reports', 310), ('data', 304), ('project', 274), ('business', 255), ('sql', 234), ('process', 222), ('database', 216), ('web', 203), ('knowledge', 203), ('worked', 189), ('involved', 176), ('integrations', 175), ('integration', 169), ('like', 168), ('client', 167), ('system', 163), ('good', 161), ('creating', 157), ('development', 156), ('support', 152), ('hcm', 150), ('working', 150), ('servers', 149), ('skills', 146), ('tools', 145), ('various', 142), ('testing', 139), ('technical', 139), ('report', 138), ('team', 137), ('design', 133), ('people', 133), ('created', 129), ('issues', 128), ('production', 128), ('react', 126), ('security', 121), ('responsibilities', 121), ('environment', 120), ('management', 118), ('services', 116), ('eib', 115), ('oracle', 115), ('domains', 115)]

# %% [markdown]
# ## Parts Of Speech (POS) Tagging

# %%
nlp = spacy.load('en_core_web_lg')

one_block = cleanedSentences[1300:5200]
doc_block = nlp(one_block)
spacy.displacy.render(doc_block, style= 'ent', jupyter= True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">ru
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     technological university kakinada professional experience tata consultancy services
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ...

# %%
for token in doc_block[:30]:
    print(token,token.pos_)
# Out:
# ru PROPN
# technological PROPN
# university PROPN
# kakinada PROPN
# professional PROPN
# experience PROPN
# tata PROPN
# consultancy PROPN
# services NOUN
# project NOUN
# support NOUN
# enhancement NOUN
# workday NOUN
# hcm PROPN
# may AUX
# till SCONJ
# date NOUN
# aims VERB
# community PROPN
# college PROPN
# usa PROPN
# workday PROPN
# hcm PROPN
# functional ADJ
# consultant NOUN
# roles VERB
# responsibilities NOUN
# responsible ADJ
# work NOUN
# workday NOUN

# %% [markdown]
# ### Filtering out only the Nouns and Verbs from the Text to Tokens

# %%
one_block = cleanedSentences
doc_block = nlp(one_block)
nouns_verbs = [token.text for token in doc_block if token.pos_ in ('NOUN','VERB')]
print(nouns_verbs[:250])
# Out:
# ['consultant', 'summary', 'consultant', 'years', 'experience', 'years', 'workday', 'experience', 'experience', 'workday', 'core', 'staffing', 'areas', 'hands', 'experience', 'configuring', 'organizations', 'business', 'process', 'creation', 'custom', 'reports', 'experienced', 'compensation', 'elements', 'configurations', 'updates', 'involved', 'requirements', 'analysis', 'integrations', 'testing', 'system', 'documentation', 'support', 'creation', 'calculated', 'fields', 'use', 'custom', 'reports', 'configuring', 'eib', 'load', 'data', 'workday', 'webservices', 'creation', 'custom', 'reports', 'requirements', 'working', 'enhancements', 'related', 'eib', 'integrations', 'custom', 'reports', 'configuration', 'changes', 'experience', 'creating', 'staffing', 'models', 'orgs', 'reorganizations', 'business', 'process', 'framework', 'organization', 'types', 'organization', 'hierarchies', 'experienced', 'developing', 'solutions', 'workday', 'platform', 'using', 'eib', 'web', 'services', 'work
# ...

# %% [markdown]
# ### Counting all the Nouns and Verbs present in the Tokens of words

# %%
cv = CountVectorizer()
X = cv.fit_transform(nouns_verbs)
sum_words = X.sum(axis=0)

words_freq = [(word,sum_words[0,idx]) for word, idx in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)

wd_df = pd.DataFrame(words_freq)
wd_df.columns = ['Words','Count']
wd_df[0:15]
# Out:
#           Words  Count
# 0    experience    512
# 1   application    368
# 2         using    367
# 3       workday    310
# 4       reports    310
# 5          data    286
# 6      business    244
# 7       project    244
# 8        server    224
# 9       process    221
# 10     database    208
# 11          web    196
# 12       worked    185
# 13    knowledge    185
# 14     involved    176

# %% [markdown]
# ### Visualizing the Result of Top 20 Nouns and Verbs most Frequently

# %%
fig, axe = plt.subplots(1,1, figsize=(10,7), dpi=200)
ax = sns.barplot(x= wd_df['Count'].head(20), y= wd_df.Words.head(20), data= wd_df, ax = axe,
            label= 'Total Pofile Category : {}'.format(len(resume_data.Category.unique())))

axe.set_xlabel('Frequency', size=16,fontweight= 'bold')
axe.set_ylabel('Words', size=16, fontweight= 'bold')
plt.xticks(rotation = 0)
plt.legend(loc='best', fontsize= 'x-large')
plt.title('Top 25 Most used Nouns and Verbs in Resumes', fontsize= 18, fontweight= 'bold')
rcParams = {'xtick.labelsize':'14','ytick.labelsize':'14','axes.labelsize':'16'}

for i in ax.containers:
    ax.bar_label(i,color = 'black', fontweight = 'bold', fontsize= 12)

pylab.rcParams.update(rcParams)
fig.tight_layout()
plt.show()

# %%
text = " ".join(cat for cat in wd_df.Words) # Creating the text variable

word_cloud = WordCloud(width=1000, height=800, random_state=10, background_color="black", 
                       colormap="Pastel1", collocations=False, stopwords=STOPWORDS).generate(text)

plt.figure(figsize=(10,7), dpi=800) # Display the generated Word Cloud
plt.title('Most used Nouns and Verbs in Resumes', fontsize= 15, fontweight= 'bold')
plt.imshow(word_cloud)
plt.axis("off")

plt.show()

# %%
# comment
